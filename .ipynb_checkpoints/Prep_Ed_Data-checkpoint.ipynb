# %% [markdown]
# This is the code I used to filter out the relevant columns for the VA educational attainment data. I also used Greg's cleaned up mobility data (and 7 day running averages) to find the maximum mobility change for each county (fips code). I added these to the ed data frame using the fips code as the join key.
#
# -Mariska (3/9/22)

# %%
import pandas as pd

#import the original data set
ed_data = pd.read_csv("EAG_Educational_Attainment_by_Locality.csv")

# %%
#view the original data set
ed_data.head()
# Out:
#       Locality  locality_fips state_name  state_fips rural_or_non_rural_flag  \
# 0        Surry          51181   Virginia          51               Non-Rural
# 1       Clarke          51043   Virginia          51               Non-Rural
# 2  Mecklenburg          51117   Virginia          51                   Rural
# 3      Augusta          51015   Virginia          51                   Rural
# 4    Goochland          51075   Virginia          51               Non-Rural
#
#    pct_no_high_school_diploma_loc  cnt_no_high_school_diploma_loc  \
# 0                        0.154303                             832
# 1                        0.106878                            1223
# 2                        0.180888                            4507
# 3                        0.129816                            7881
# 4                        0.095134                            1789
#
#    pct_high_school_grad_loc  cnt_total_high_school_grad_loc  \
# 0                  0.371662                            4560
# 1                  0.297387                           10220
# 2                  0.328303                           20409
# 3                  0.392281                           52828
# 4                  0.242382                           17016
#
#    pct_total_high_school_grad_loc  ...  pct_high_school_grad_Hispanic_loc  \
# 0                        0.845697  ...                              0.878
# 1                        0.893122  ...                              0.751
# 2                        0.819112  ...                              0.697
# 3                        0.870184  ...                              0.571
# 4                        0.904866  ...                              0.830
#
#    pct_bachelors_degree_Caucasian_loc  pct_bachelors_degree_Black_loc  \
# 0                               0.225                           0.177
# 1                               0.333                           0.278
# 2                               0.256                           0.107
# 3                               0.236                           0.053
# 4                               0.474                           0.148
#
#    pct_bachelors_degree_Asian_loc  pct_bachelors_degree_Hispanic_loc  \
# 0                           0.000                              0.293
# 1                           0.149                              0.155
# 2                           0.130                              0.122
# 3                           0.707                              0.114
# 4                           0.761                              0.308
#
#    pct_poverty_education_no_high_school_loc  \
# 0                                     0.245
# 1                                     0.161
# 2                                     0.322
# 3                                     0.163
# 4                                     0.105
#
#    pct_poverty_education_high_school_loc  \
# 0                                  0.150
# 1                                  0.102
# 2                                  0.185
# 3                                  0.092
# 4                                  0.083
#
#    pct_poverty_education_bachelors_or_higher_loc  pct_pursuing_HighEd_All  \
# 0                                          0.052                     0.66
# 1                                          0.025                     0.75
# 2                                          0.070                     0.65
# 3                                          0.030                     0.58
# 4                                          0.026                     0.66
#
#    cnt_pursuing_HighEd_All
# 0                       39
# 1                      131
# 2                      186
# 3                      413
# 4                      142
#
# [5 rows x 34 columns]

# %%
#create a new dataframe with selected columns

ed_new = ed_data[['Locality','locality_fips','rural_or_non_rural_flag', 'pct_no_high_school_diploma_loc', 'pct_high_school_grad_loc','pct_Some_College_Associates_loc','pct_bachelors_degree_+_loc', 'pct_total_high_school_grad_loc']]
ed_new.head(3)
# Out:
#       Locality  locality_fips rural_or_non_rural_flag  \
# 0        Surry          51181               Non-Rural
# 1       Clarke          51043               Non-Rural
# 2  Mecklenburg          51117                   Rural
#
#    pct_no_high_school_diploma_loc  pct_high_school_grad_loc  \
# 0                        0.154303                  0.371662
# 1                        0.106878                  0.297387
# 2                        0.180888                  0.328303
#
#    pct_Some_College_Associates_loc  pct_bachelors_degree_+_loc  \
# 0                         0.276335                    0.197700
# 1                         0.296426                    0.299310
# 2                         0.304704                    0.186105
#
#    pct_total_high_school_grad_loc
# 0                        0.845697
# 1                        0.893122
# 2                        0.819112

# %%
#import and view the cleaned mobility data set from Greg
mobility = pd.read_csv('Google_Mob_VA_peakdates_clean.csv')
mobility.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21406 entries, 0 to 21405
# Data columns (total 17 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Unnamed: 0                          21406 non-null  int64
#  1   index                               21406 non-null  int64
#  2   date                                21406 non-null  object
#  3   state                               21406 non-null  object
#  4   county                              21406 non-null  object
#  5   census_fips_code                    15152 non-null  float64
#  6   retail                              14000 non-null  float64
#  7   grocery                             13282 non-null  float64
#  8   parks                               2863 non-null   float64
#  9   transit                             7306 non-null   float64
#  10  workplaces                          20373 non-null  float64
#  11  residential                         8272 non-null   float64
#  12  Non_Residential                     21230 non-null  float64
#  13  Non_Residential_7d_Rolling          21050 non-null  float64
#  14  Residential_7d_Rolling              4171 non-null   float64
#  15  Minimum_Non_Residential_7d_Rolling  21406 non-null  float64
#  16  Low_Point_Mobility                  21406 non-null  int64
# dtypes: float64(11), int64(3), object(3)
# memory usage: 2.8+ MB

# %%
#drop rows with missing fips code
mobility.dropna(subset=['census_fips_code'], inplace=True)

#convert fips code to integer
mobility.census_fips_code = mobility.census_fips_code.astype(int)

# %%
#unit test to check that fips code type is changed

from unittest import TestCase

#check that fips code column is an int

actual = mobility.census_fips_code.dtype
expected = "int64"

#create test case object
tc=TestCase()

#run a test asserting equality; should return None
print(tc.assertEqual(actual, expected))
# Out:
# None

# %%
#for each fips code, find min Non-Residential 7-d rolling (which is a % change from baseline; negaive values are a decrease)
max_change = mobility.groupby('census_fips_code')[['Non_Residential_7d_Rolling']].min() #[[ stores output as a data frame, rather than series

# %%
max_change.head(10)
# Out:
#                   Non_Residential_7d_Rolling
# census_fips_code
# 51001                             -24.428571
# 51003                             -44.000000
# 51005                             -28.071429
# 51007                             -39.357143
# 51009                             -26.714286
# 51011                             -32.285714
# 51013                             -59.514286
# 51015                             -30.897619
# 51017                             -68.428571
# 51019                             -47.142857

# %%
#add to ed_new

ed_new = ed_new.merge(max_change, how='inner', left_on='locality_fips', right_on='census_fips_code')

# %%
# add column that converts "non-residential 7d rolling" to "max_mob_reduction"
ed_new["max_mob_reduction"] = ed_new.apply(lambda row: row.Non_Residential_7d_Rolling*-1, axis=1)

# %%
#export the new data frame as a CSV file
ed_new.to_csv('VA_ed_data_cleaned.csv')

# %%
#check new file
data = pd.read_csv('VA_ed_data_cleaned.csv')
data.head()
# Out:
#    Unnamed: 0     Locality  locality_fips rural_or_non_rural_flag  \
# 0           0        Surry          51181               Non-Rural
# 1           1       Clarke          51043               Non-Rural
# 2           2  Mecklenburg          51117                   Rural
# 3           3      Augusta          51015                   Rural
# 4           4    Goochland          51075               Non-Rural
#
#    pct_no_high_school_diploma_loc  pct_high_school_grad_loc  \
# 0                        0.154303                  0.371662
# 1                        0.106878                  0.297387
# 2                        0.180888                  0.328303
# 3                        0.129816                  0.392281
# 4                        0.095134                  0.242382
#
#    pct_Some_College_Associates_loc  pct_bachelors_degree_+_loc  \
# 0                         0.276335                    0.197700
# 1                         0.296426                    0.299310
# 2                         0.304704                    0.186105
# 3                         0.260159                    0.217744
# 4                         0.267854                    0.394629
#
#    pct_total_high_school_grad_loc  Non_Residential_7d_Rolling  \
# 0                        0.845697                  -40.285714
# 1                        0.893122                  -46.142857
# 2                        0.819112                  -27.535714
# 3                        0.870184                  -30.897619
# 4                        0.904866                  -46.428571
#
#    max_mob_reduction
# 0          40.285714
# 1          46.142857
# 2          27.535714
# 3          30.897619
# 4          46.428571

# %%
#change column name
data.rename(columns={'pct_bachelors_degree_+_loc':'pct_bachelors_plus', 'pct_total_high_school_grad_loc':'pct_HS_grad_total'}, inplace=True)
data.head()
# Out:
#    Unnamed: 0     Locality  locality_fips rural_or_non_rural_flag  \
# 0           0        Surry          51181               Non-Rural
# 1           1       Clarke          51043               Non-Rural
# 2           2  Mecklenburg          51117                   Rural
# 3           3      Augusta          51015                   Rural
# 4           4    Goochland          51075               Non-Rural
#
#    pct_no_high_school_diploma_loc  pct_high_school_grad_loc  \
# 0                        0.154303                  0.371662
# 1                        0.106878                  0.297387
# 2                        0.180888                  0.328303
# 3                        0.129816                  0.392281
# 4                        0.095134                  0.242382
#
#    pct_Some_College_Associates_loc  pct_bachelors_plus  pct_HS_grad_total  \
# 0                         0.276335            0.197700           0.845697
# 1                         0.296426            0.299310           0.893122
# 2                         0.304704            0.186105           0.819112
# 3                         0.260159            0.217744           0.870184
# 4                         0.267854            0.394629           0.904866
#
#    Non_Residential_7d_Rolling  max_mob_reduction
# 0                  -40.285714          40.285714
# 1                  -46.142857          46.142857
# 2                  -27.535714          27.535714
# 3                  -30.897619          30.897619
# 4                  -46.428571          46.428571

# %%
#plot max_mob_red versus pct_bachelors_plus

import matplotlib.pyplot as plt

x=data['pct_bachelors_plus']
y=data['max_mob_reduction']
plt.scatter(x, y, c="blue")
plt.xlabel("% Residents with Bachelor's Degree or Above")
plt.ylabel("Max % Reduction in Mobility (7-Day Rolling Average")
plt.show()

# %%
#repeat the plot above, but color points by rural or non-rural

groups = data.groupby('rural_or_non_rural_flag')
for name, group in groups:
    plt.scatter(group.pct_bachelors_plus, group.max_mob_reduction, label = name)

plt.legend()
plt.xlabel("% Residents with Bachelor's Degree or Above")
plt.ylabel("Max % Reduction in Mobility (7-Day Rolling Average")
# Out:
# Text(0, 0.5, 'Max % Reduction in Mobility (7-Day Rolling Average')

# %%
#What happens when we look at % with HS graduation as their highest level of ed attainment?
for name, group in groups:
    plt.scatter(group.pct_high_school_grad_loc, group.max_mob_reduction, label = name)

plt.legend()
plt.xlabel("% Residents with High School Diploma as Highest Level of Education")
plt.ylabel("Max % Reduction in Mobility (7-Day Rolling Average")
# Out:
# Text(0, 0.5, 'Max % Reduction in Mobility (7-Day Rolling Average')

# %%
#What happens when we look at the total % who graduated from HS? (Irrespective of max ed attainment)
for name, group in groups:
    plt.scatter(group.pct_HS_grad_total, group.max_mob_reduction, label = name)

plt.legend()
plt.xlabel("% Residents Graduated from High School")
plt.ylabel("Max % Reduction in Mobility (7-Day Rolling Average")
# Out:
# Text(0, 0.5, 'Max % Reduction in Mobility (7-Day Rolling Average')
