# %% [markdown]
# *Reading in Google Mobility Data:
#
# Note: data are read as "percent change from baseline"
#
# This was my R code:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading in dataframe and filtering for State of Virginia

# %%
#this takes a long while to run and is a huge file so I did this once and saved a smaller, csv file filtered to Virginia

#Google_Mob = pd.read_csv("https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv?cachebust=6d352e35dcffafce")
# #Google_Mob = pd.read_csv("https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv?cachebust=6d352e35dcffafce", dtype={'country_region_code': 'str', 'country_region': 'str', 'sub_region_1': 'str', 'sub_region_2': 'str', 'metro_area': 'str', 'iso_3166_2_code': 'str', 'census_fips_code': 'np.int64', 'place_id': 'str', 'date': 'np.datetime64', 'retail_and_recreation_percent_change_from_baseline': 'np.float64', 'grocery_and_pharmacy_percent_change_from_baseline': 'np.float64', 'parks_percent_change_from_baseline': 'np.float64', 'transit_stations_percent_change_from_baseline': 'np.float64', 'workplaces_percent_change_from_baseline': 'np.float64', 'residential_percent_change_from_baseline': 'np.float64' })
#Google_Mob_VA = Google_Mob[(Google_Mob.country_region == "United States") & (Google_Mob.sub_region_1 == "Virginia")] #filtering for Virginia, USA
#del Google_Mob
# Google_Mob_VA.to_csv("./google_mobility_VA.csv")

# %%
Google_Mob_VA = pd.read_csv("./google_mobility_VA.csv")
# Out:
# /Users/grgmadden/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Google_Mob_VA['date'] = pd.to_datetime(Google_Mob_VA['date']) #change to date format.

# %%
Google_Mob_VA.columns
Google_Mob_VA.dtypes
# Out:
# country_region_code                                           object
# country_region                                                object
# sub_region_1                                                  object
# sub_region_2                                                  object
# metro_area                                                   float64
# iso_3166_2_code                                               object
# census_fips_code                                             float64
# place_id                                                      object
# date                                                  datetime64[ns]
# retail_and_recreation_percent_change_from_baseline           float64
# grocery_and_pharmacy_percent_change_from_baseline            float64
# parks_percent_change_from_baseline                           float64
# transit_stations_percent_change_from_baseline                float64
# workplaces_percent_change_from_baseline                      float64
# residential_percent_change_from_baseline                     float64
# dtype: object

# %% [markdown]
# Renaming State, Counties

# %%
Google_Mob_VA = Google_Mob_VA.rename(columns={"sub_region_1": "state", "sub_region_2": "county"}) #rename state, county columns

# %%
Google_Mob_VA = Google_Mob_VA.drop(['iso_3166_2_code', 'place_id'], axis=1) #dropping unnecessary columns

# %%
#checking
Google_Mob_VA.columns
# Out:
# Index(['country_region_code', 'country_region', 'state', 'county',
#        'metro_area', 'census_fips_code', 'date',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline'],
#       dtype='object')

# %%
Google_Mob_VA.dtypes
# Out:
# country_region_code                                           object
# country_region                                                object
# state                                                         object
# county                                                        object
# metro_area                                                   float64
# census_fips_code                                             float64
# date                                                  datetime64[ns]
# retail_and_recreation_percent_change_from_baseline           float64
# grocery_and_pharmacy_percent_change_from_baseline            float64
# parks_percent_change_from_baseline                           float64
# transit_stations_percent_change_from_baseline                float64
# workplaces_percent_change_from_baseline                      float64
# residential_percent_change_from_baseline                     float64
# dtype: object

# %%
#using same masking technique that Wenwei employed here. 
start_date = '03-01-2020'
end_date = '09-01-2020'

mask = (Google_Mob_VA['date'] > start_date) & (Google_Mob_VA['date'] <= end_date)
#assign mask to df to return the rows with _date between our specified start/end dates

Google_Mob_VA_peakdates = Google_Mob_VA.loc[mask] #specified the date range to be within 1st 6 months of pandemic onset.
#NYTCovid_peakdates

# %%
#checking date range
Google_Mob_VA_peakdates.date.describe(datetime_is_numeric=True)
# Out:
# count                            21590
# mean     2020-05-27 04:51:28.096340736
# min                2020-03-02 00:00:00
# 25%                2020-04-13 00:00:00
# 50%                2020-05-27 00:00:00
# 75%                2020-07-10 00:00:00
# max                2020-09-01 00:00:00
# Name: date, dtype: object

# %%
display(Google_Mob_VA_peakdates)
# Out:
#       country_region_code country_region     state       county  metro_area  \
# 16                     US  United States  Virginia          NaN         NaN
# 17                     US  United States  Virginia          NaN         NaN
# 18                     US  United States  Virginia          NaN         NaN
# 19                     US  United States  Virginia          NaN         NaN
# 20                     US  United States  Virginia          NaN         NaN
# ...                   ...            ...       ...          ...         ...
# 86659                  US  United States  Virginia  York County         NaN
# 86660                  US  United States  Virginia  York County         NaN
# 86661                  US  United States  Virginia  York County         NaN
# 86662                  US  United States  Virginia  York County         NaN
# 86663                  US  United States  Virginia  York County         NaN
#
#        census_fips_code       date  \
# 16                  NaN 2020-03-02
# 17                  NaN 2020-03-03
# 18                  NaN 2020-03-04
# 19                  NaN 2020-03-05
# 20                  NaN 2020-03-06
# ...                 ...        ...
# 86659           51199.0 2020-08-27
# 86660           51199.0 2020-08-28
# 86661           51199.0 2020-08-29
# 86662           51199.0 2020-08-31
# 86663           51199.0 2020-09-01
#
#        retail_and_recreation_percent_change_from_baseline  \
# 16                                                   7.0
# 17                                                  14.0
# 18                                                   9.0
# 19                                                   6.0
# 20                                                   3.0
# ...                                                  ...
# 86659                                               -4.0
# 86660                                               -6.0
# 86661                                               -7.0
# 86662                                                NaN
# 86663                                                NaN
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 16                                                   5.0
# 17                                                  10.0
# 18                                                   8.0
# 19                                                   6.0
# 20                                                   1.0
# ...                                                  ...
# 86659                                                NaN
# 86660                                                NaN
# 86661                                                NaN
# 86662                                                NaN
# 86663                                                NaN
#
#        parks_percent_change_from_baseline  \
# 16                                   20.0
# 17                                   40.0
# 18                                   39.0
# 19                                   19.0
# 20                                    5.0
# ...                                   ...
# 86659                                 NaN
# 86660                                 NaN
# 86661                                 NaN
# 86662                                 NaN
# 86663                                 NaN
#
#        transit_stations_percent_change_from_baseline  \
# 16                                               2.0
# 17                                               2.0
# 18                                               5.0
# 19                                               4.0
# 20                                               3.0
# ...                                              ...
# 86659                                            NaN
# 86660                                            NaN
# 86661                                            NaN
# 86662                                            NaN
# 86663                                            NaN
#
#        workplaces_percent_change_from_baseline  \
# 16                                         5.0
# 17                                        -4.0
# 18                                         2.0
# 19                                         2.0
# 20                                         1.0
# ...                                        ...
# 86659                                    -43.0
# 86660                                    -41.0
# 86661                                      NaN
# 86662                                    -40.0
# 86663                                    -40.0
#
#        residential_percent_change_from_baseline
# 16                                         -1.0
# 17                                          0.0
# 18                                         -1.0
# 19                                         -1.0
# 20                                          0.0
# ...                                         ...
# 86659                                      13.0
# 86660                                      12.0
# 86661                                       NaN
# 86662                                      11.0
# 86663                                      12.0
#
# [21590 rows x 13 columns]

# %%
#dropping rows with missing county data
Google_Mob_VA_peakdates = Google_Mob_VA_peakdates.dropna(subset=['county'])

# %%
display(Google_Mob_VA_peakdates)
# Out:
#       country_region_code country_region     state           county  \
# 745                    US  United States  Virginia  Accomack County
# 746                    US  United States  Virginia  Accomack County
# 747                    US  United States  Virginia  Accomack County
# 748                    US  United States  Virginia  Accomack County
# 749                    US  United States  Virginia  Accomack County
# ...                   ...            ...       ...              ...
# 86659                  US  United States  Virginia      York County
# 86660                  US  United States  Virginia      York County
# 86661                  US  United States  Virginia      York County
# 86662                  US  United States  Virginia      York County
# 86663                  US  United States  Virginia      York County
#
#        metro_area  census_fips_code       date  \
# 745           NaN           51001.0 2020-03-02
# 746           NaN           51001.0 2020-03-03
# 747           NaN           51001.0 2020-03-04
# 748           NaN           51001.0 2020-03-05
# 749           NaN           51001.0 2020-03-06
# ...           ...               ...        ...
# 86659         NaN           51199.0 2020-08-27
# 86660         NaN           51199.0 2020-08-28
# 86661         NaN           51199.0 2020-08-29
# 86662         NaN           51199.0 2020-08-31
# 86663         NaN           51199.0 2020-09-01
#
#        retail_and_recreation_percent_change_from_baseline  \
# 745                                                  9.0
# 746                                                 18.0
# 747                                                 11.0
# 748                                                  6.0
# 749                                                  1.0
# ...                                                  ...
# 86659                                               -4.0
# 86660                                               -6.0
# 86661                                               -7.0
# 86662                                                NaN
# 86663                                                NaN
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 745                                                  8.0
# 746                                                  8.0
# 747                                                  9.0
# 748                                                  8.0
# 749                                                  3.0
# ...                                                  ...
# 86659                                                NaN
# 86660                                                NaN
# 86661                                                NaN
# 86662                                                NaN
# 86663                                                NaN
#
#        parks_percent_change_from_baseline  \
# 745                                   NaN
# 746                                   NaN
# 747                                   NaN
# 748                                   NaN
# 749                                   NaN
# ...                                   ...
# 86659                                 NaN
# 86660                                 NaN
# 86661                                 NaN
# 86662                                 NaN
# 86663                                 NaN
#
#        transit_stations_percent_change_from_baseline  \
# 745                                              NaN
# 746                                              NaN
# 747                                              NaN
# 748                                              NaN
# 749                                              NaN
# ...                                              ...
# 86659                                            NaN
# 86660                                            NaN
# 86661                                            NaN
# 86662                                            NaN
# 86663                                            NaN
#
#        workplaces_percent_change_from_baseline  \
# 745                                        5.0
# 746                                        2.0
# 747                                        2.0
# 748                                        3.0
# 749                                        1.0
# ...                                        ...
# 86659                                    -43.0
# 86660                                    -41.0
# 86661                                      NaN
# 86662                                    -40.0
# 86663                                    -40.0
#
#        residential_percent_change_from_baseline
# 745                                         1.0
# 746                                        -2.0
# 747                                        -2.0
# 748                                        -1.0
# 749                                         3.0
# ...                                         ...
# 86659                                      13.0
# 86660                                      12.0
# 86661                                       NaN
# 86662                                      11.0
# 86663                                      12.0
#
# [21406 rows x 13 columns]

# %%
#writing cleaned dataset to csv
Google_Mob_VA_peakdates.to_csv("./Google_Mob_VA_peakdates_cleaned.csv")
